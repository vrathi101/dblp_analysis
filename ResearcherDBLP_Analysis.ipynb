# %% [markdown]
# <a href="https://colab.research.google.com/github/vrathi101/dblp_analysis/blob/main/ResearcherDBLP_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import gzip
from lxml import etree
import pandas as pd

# %% [markdown]
# **Get DBLP XML Data**
# The dblp computer science bibliography provides open bibliographic information on major computer science journals and proceedings

# %%
#url of the gzipped XML file
url = "https://dblp.uni-trier.de/xml/dblp.xml.gz"
#make a GET request to fetch the gzipped XML content
response = requests.get(url)
#save the content to a file
with open("dblp.xml.gz", "wb") as f:
  f.write(response.content)

# %%
#save the content to a file
with open("dblp.xml.gz", "wb") as f:
  f.write(response.content)

# %% [markdown]
# Read the Researchers Google Sheet as a csv  - This CSV contains data about researchers (committee members) from CoNEXT, Sigcomm, and NSDI PC. We want to find their publications in DBLP XML.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
proj_path = '/content/gdrive/MyDrive/Colab Notebooks/save_data/'
dfResearcher = pd.read_csv(proj_path + 'researchers.csv')
dfResearcher.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#               Name  Google Scholar Link                           email  \
# 0  Sergey Gorinsky                  NaN       sergey.gorinsky@imdea.org
# 1   Hitesh Ballani                  NaN    hitesh.ballani@microsoft.com
# 2     Haya Shulman                  NaN  haya.shulman@sit.fraunhofer.de
# 3  Rüdiger Birkner                  NaN                mail@rbirkner.ch
# 4     Klaus Wehrle                  NaN    wehrle@comsys.rwth-aachen.de
#
#                                      Institution                Expertise  \
# 0                                          IMDEA  CDN,CLOUD-DC,ECONOMICS,
# 1                             Microsoft Research        CLOUD-DC,ROUTING,
# 2  Fraunhofer and Hebrew university of Jerusalem                SECURITY,
# 3                                            ???                     SDN,
# 4                              Aachen University   VERIFICATION,SECURITY,
#
#   Region Approximate PhD Graduation Year  Female or NB  \
# 0     EU                          senior           NaN
# 1     EU                          senior           NaN
# 2     EU                             NaN           1.0
# 3     EU                            2018           NaN
# 4     EU                          senior           NaN
#
#   Minority (Race if known)  Industry
# 0                      NaN       NaN
# 1                      NaN       NaN
# 2                      NaN       1.0
# 3                      NaN       NaN
# 4                      NaN       NaN

# %% [markdown]
# Remove some unnecessary columns

# %%
dfResearcher = dfResearcher.drop(['Google Scholar Link', 'Minority (Race if known)'], axis=1, errors='ignore')
dfResearcher.head()
# Out:
#               Name                           email  \
# 0  Sergey Gorinsky       sergey.gorinsky@imdea.org
# 1   Hitesh Ballani    hitesh.ballani@microsoft.com
# 2     Haya Shulman  haya.shulman@sit.fraunhofer.de
# 3  Rüdiger Birkner                mail@rbirkner.ch
# 4     Klaus Wehrle    wehrle@comsys.rwth-aachen.de
#
#                                      Institution                Expertise  \
# 0                                          IMDEA  CDN,CLOUD-DC,ECONOMICS,
# 1                             Microsoft Research        CLOUD-DC,ROUTING,
# 2  Fraunhofer and Hebrew university of Jerusalem                SECURITY,
# 3                                            ???                     SDN,
# 4                              Aachen University   VERIFICATION,SECURITY,
#
#   Region Approximate PhD Graduation Year  Female or NB  Industry
# 0     EU                          senior           NaN       NaN
# 1     EU                          senior           NaN       NaN
# 2     EU                             NaN           1.0       1.0
# 3     EU                            2018           NaN       NaN
# 4     EU                          senior           NaN       NaN

# %% [markdown]
# Merge the XML and the CSV and print few records

# %%
import random
import gzip
from lxml import etree

# Function to extract author names
def extract_authors(element):
    authors = []
    for author_elem in element.xpath("author"):
        authors.append(author_elem.text)
    return authors

# Create a dictionary to store XML records indexed by researcher name
xml_records = {}

# Process the DBLP XML file
with gzip.open("dblp.xml.gz", "rb") as f:
    context = etree.iterparse(f, events=("start", "end"), recover=True)

    for event, element in context:
        if element.tag == 'article':
            # Extract the article key, title, authors, and year
            article_key = element.get('key')
            article_title = element.xpath('title')
            if article_title:
                article_title = article_title[0].text
            else:
                article_title = 'N/A'
            article_authors = extract_authors(element)
            article_year = element.xpath('year')
            if article_year:
                article_year = article_year[0].text
            else:
                article_year = 'N/A'

            # Add the record to the dictionary indexed by each author's name
            for author in article_authors:
                if author not in xml_records:
                    xml_records[author] = []
                xml_records[author].append({
                    'key': article_key,
                    'title': article_title,
                    'authors': article_authors,
                    'year': article_year
                })

        # Clear the processed elements to free up memory
        element.clear()

# Get the common authors between CSV and DBLP
common_authors = set(dfResearcher['Name']).intersection(xml_records.keys())

# Print three random authors from the common set
random_authors = random.sample(common_authors, k=3)

for author in random_authors:
    # Print the researcher name and their corresponding information
    print('Researcher:', author)
    print('Google Sheets Data:')
    print(dfResearcher[dfResearcher['Name'] == author])
    print('XML Records:')
    for record in xml_records[author]:
        print(record)
    print('---')
# Out:
# Researcher: Krishna P. Gummadi
# Google Sheets Data:
#                    Name                email            Institution  \
# 496  Krishna P. Gummadi  gummadi@mpi-sws.org  Max Planck Institute
#
#                      Expertise Region Approximate PhD Graduation Year  \
# 496  SYSTEMS,SECURITY,NETWORKS     EU                            2005
#
#      Female or NB  Industry
# 496           NaN       1.0
# XML Records:
# {'key': 'journals/jmlr/ZafarVGG19', 'title': 'Fairness Constraints: A Flexible Approach for Fair Classification.', 'authors': ['Muhammad Bilal Zafar', 'Isabel Valera', 'Manuel Gomez-Rodriguez', 'Krishna P. Gummadi'], 'year': '2019'}
# {'key': 'journals/internet/MondalMGGK17', 'title': 'Longitudinal Privacy Management in Social Media: The Need for Better Controls.', 'authors': ['Mainack Mondal', 'Johnnatan Messias', 'Saptarshi Ghosh 0001', 'Krishna P. Gummadi', 'Aniket Kate'], 'year': '2017'}
# {'key': 'journals/popets/MinaeiMLGK19', 'title': 'Lethe: Conceal Content Deletion from Persistent Observers.', 'authors': ['Mohsen Minaei', 'Mainack Mondal', 'Patrick Loiseau', 'Krishna P. Gummadi', 'Aniket Kate'], 'year': '2019'}
# {'key': 'journals/pacmhci/MotaCBGH20', 'title': 'On the Desiderata for Online Altruism: Nudging for Equitable Donations.', 'authors': ['Nuno Mota', 'Abhijnan Chakraborty', 'Asia J. Biega', 'Krishna P. Gummadi', 'Hoda Heidari'], 'year': '2020'}
# {'key': 'journals/pacmhci/Grgic-HlacaEG19', 'title': 'Human Decision Making with Machine Assistance: An Experiment on Bailing and Jailing.', 'authors': ['Nina Grgic-Hlaca', 'Christoph Engel', 'Krishna P. Gummadi'], 'year': '2019'}
# {'key': 'journals/tcss/BabaeiKCRCG22', 'title': 'Analyzing Biases in Perception of Truth in News Stories and Their Implications for Fact Checking.', 'authors': ['Mahmoudreza Babaei', 'Juhi Kulshrestha', 'Abhijnan Chakraborty', 'Elissa M. Redmiles', 'Meeyoung Cha', 'Krishna P. Gummadi'], 'year': '2022'}
# {'key': 'journals/tcss/ChakrabortyGGG19', 'title': 'Editorial Versus Audience Gatekeeping: Analyzing News Selection and Consumption Dynamics in Online News Media.', 'authors': ['Abhijnan Chakraborty', 'Saptarshi Ghosh 0001', 'Niloy Ganguly', 'Krishna P. Gummadi'], 'year': '2019'}
# {'key': 'journals/tweb/BiswasPGGC22', 'title': 'Toward Fair Recommendation in Two-sided Platforms.', 'authors': ['Arpita Biswas', 'Gourab K. Patro', 'Niloy Ganguly', 'Krishna P. Gummadi', 'Abhijnan Chakraborty'], 'year': '2022'}
# {'key': 'journals/tweb/ZafarBGGG15', 'title': 'Sampling Content from Online Social Networks: Comparing Random vs. Expert Sampling of the Twitter Stream.', 'authors': ['Muhammad Bilal Zafar', 'Parantapa Bhattacharya', 'Niloy Ganguly', 'Krishna P. Gummadi', 'Saptarshi Ghosh 0001'], 'year': '2015'}
# {'key': 'journals/ccr/SenAPFQCG17', 'title': "Inside the Walled Garden: Deconstructing Facebook's Free Basics Program.", 'authors': ['Rijurekha Sen', 'Sohaib Ahmad', 'Amreesh Phokeer', 'Zaid Ahmed Farooq', 'Ihsan Ayyub Qazi', 'David R. Choffnes', 'Krishna P. Gummadi'], 'year': '2017'}
# {'key': 'journals/ai/EmelianovGGL22', 'title': 'On fair selection in the presence of implicit and differential variance.', 'authors': ['Vitalii Emelianov', 'Nicolas Gast', 'Krishna P. Gummadi', 'Patrick Loiseau'], 'year': '2022'}
# {'key': 'journals/ir/ChakrabortyGGG19', 'title': 'Optimizing the recency-relevance-diversity trade-offs in non-personalized news recommendations.', 'authors': ['Abhijnan Chakraborty', 'Saptarshi Ghosh 0001', 'Niloy Ganguly', 'Krishna P. Gummadi'], 'year': '2019'}
# {'key': 'journals/ir/KulshresthaEMZG19', 'title': 'Search bias quantification: investigating political bias in social media and web search.', 'authors': ['Juhi Kulshrestha', 'Motahhare Eslami', 'Johnnatan Messias', 'Muhammad Bilal Zafar', 'Saptarshi Ghosh 0001', 'Krishna P. Gummadi', 'Karrie Karahalios'], 'year': '2019'}
# {'key': 'journals/tkde/AliBCMGS23', 'title': 'On the Fairness of Time-Critical Influence Maximization in Social Networks.', 'authors': ['Junaid Ali 0001', 'Mahmoudreza Babaei', 'Abhijnan Chakraborty', 'Baharan Mirzasoleiman', 'Krishna P. Gummadi', 'Adish Singla'], 'year': '2023'}
# {'key': 'journals/corr/abs-2102-00141', 'title': 'When the Umpire is also a Player: Bias in Private Label Product Recommendations on E-commerce Marketplaces.', 'authors': ['Abhisek Dash', 'Abhijnan Chakraborty', 'Saptarshi Ghosh 0001', 'Animesh Mukherjee 0001', 'Krishna P. Gummadi'], 'year': '2021'}
# {'key': 'journals/corr/abs-1809-03400', 'title': 'A Moral Framework for Understanding of Fair ML through Economic Models of Equality of Opportunity.', 'authors': ['Hoda Heidari', 'Michele Loi', 'Krishna P. Gummadi', 'Andreas Krause 0001'], 'year': '2018'}
# {'key': 'journals/corr/abs-2204-00241', 'title': 'FaiRIR: Mitigating Exposure Bias from Related Item Recommendations in Two-Sided Platforms.', 'authors': ['Abhisek Dash', 'Abhijnan Chakraborty', 'Saptarshi Ghosh 0001', 'Animesh Mukherjee 0001', 'Krishna P. Gummadi'], 'year': '2022'}
# {'key': 'journals/corr/BabaeiGVGG16', 'title': 'On the Efficiency of the Information Networks in Social Media.', 'authors': ['Mahmoudreza Babaei', 'Przemyslaw A. Grabowicz', 'Isabel Valera', 'Krishna P. Gummadi', 'Manuel Gomez-Rodriguez'], 'year': '2016'}
# {'key': 'journals/corr/abs-2007-00251', 'title': 'Unifying Model Explainability and Robustness via Machine-Checkable Concepts.', 'authors': ['Vedant Nanda', 'Till Speicher', 'John P. Dickerson', 'Krishna P. Gummadi', 'Muhammad Bilal Zafar'], 'year': '2020'}
# {'key': 'journals/corr/abs-1806-01059', 'title': 'iFair: Learning Individually Fair Data Representations for Algorithmic Decision Making.', 'authors': ['Preethi Lahoti', 'Gerhard Weikum', 'Krishna P. Gummadi'], 'year': '2018'}
# {'key': 'journals/corr/abs-1807-00787', 'title': 'A Unified Approach to Quantifying Algorithmic Unfairness: Measuring Individual  Group Unfairness via Inequality Indices.', 'authors': ['Till Speicher', 'Hoda Heidari', 'Nina Grgic-Hlaca', 'Krishna P. Gummadi', 'Adish Singla', 'Adrian Weller', 'Muhammad Bilal Zafar'], 'year': '2018'}
# {'key': 'journals/corr/abs-1806-04959', 'title': 'Fairness Behind a Veil of Ignorance: A Welfare Analysis for Automated Decision Making.', 'authors': ['Hoda Heidari', 'Claudio Ferrari', 'Krishna P. Gummadi', 'Andreas Krause 0001'], 'year': '2018'}
# {'key': 'journals/corr/abs-2205-04790', 'title': "Don't Throw it Away! The Utility of Unlabeled Data in Fair Decision Making.", 'authors': ['Miriam Rateike', 'Ayan Majumdar', 'Olga Mineeva', 'Krishna P. Gummadi', 'Isabel Valera'], 'year': '2022'}
# {'key': 'journals/corr/abs-1708-00670', 'title': 'On Quantifying Knowledge Segregation in Society.', 'authors': ['Abhijnan Chakraborty', 'Muhammad Ali', 'Saptarshi Ghosh 0001', 'Niloy Ganguly', 'Krishna P. Gummadi'], 'year': '2017'}
# {'key': 'journals/corr/abs-2204-12062', 'title': 'Scheduling Virtual Conferences Fairly: Achieving Equitable Participant and Speaker Satisfaction.', 'authors': ['Gourab K. Patro', 'Prithwish Jana', 'Abhijnan Chakraborty', 'Krishna P. Gummadi', 'Niloy Ganguly'], 'year': '2022'}
# {'key': 'journals/corr/abs-2005-09209', 'title': 'Fair Inputs and Fair Outputs: The Incompatibility of Fairness in Privacy and Accuracy.', 'authors': ['Bashir Rastegarpanah', 'Mark Crovella', 'Krishna P. Gummadi'], 'year': '2020'}
# {'key': 'journals/corr/abs-2112-05630', 'title': 'On Fair Selection in the Presence of Implicit and Differential Variance.', 'authors': ['Vitalii Emelianov', 'Nicolas Gast', 'Krishna P. Gummadi', 'Patrick Loiseau'], 'year': '2021'}
# {'key': 'journals/corr/abs-2105-02725', 'title': 'CrossWalk: Fairness-enhanced Node Representation Learning.', 'authors': ['Ahmad Khajehnejad', 'Moein Khajehnejad', 'Mahmoudreza Babaei', 'Krishna P. Gummadi', 'Adrian Weller', 'Baharan Mirzasoleiman'], 'year': '2021'}
# {'key': 'journals/corr/ChakrabortyMBGG17', 'title': 'Who Makes Trends? Understanding Demographic Biases in Crowdsourced Recommendations.', 'authors': ['Abhijnan Chakraborty', 'Johnnatan Messias', 'Fabr', 'Saptarshi Ghosh 0001', 'Niloy Ganguly', 'Krishna P. Gummadi'], 'year': '2017'}
# {'key': 'journals/corr/KulshresthaEMZG17', 'title': 'Quantifying Search Bias: Investigating Sources of Bias for Political Searches in Social Media.', 'authors': ['Juhi Kulshrestha', 'Motahhare Eslami', 'Johnnatan Messias', 'Muhammad Bilal Zafar', 'Saptarshi Ghosh 0001', 'Krishna P. Gummadi', 'Karrie Karahalios'], 'year': '2017'}
# {'key': 'journals/corr/abs-2201-07726', 'title': '"Learn the Facts About COVID-19": Analyzing the Use of Warning Labels on TikTok Videos.', 'authors': ['Chen Ling', 'Krishna P. Gummadi', 'Savvas Zannettou'], 'year': '2022'}
# {'key': 'journals/corr/abs-1903-01209', 'title': 'On the Long-term Impact of Algorithmic Decision Policies: Effort Unfairness and Feature Segregation through Social Learning.', 'authors': ['Hoda Heidari', 'Vedant Nanda', 'Krishna P. Gummadi'], 'year': '2019'}
# {'key': 'journals/corr/abs-2109-04432', 'title': 'Detecting and Mitigating Test-time Failure Risks via Model-agnostic Uncertainty Learning.', 'authors': ['Preethi Lahoti', 'Krishna P. Gummadi', 'Gerhard Weikum'], 'year': '2021'}
# {'key': 'journals/corr/Grgic-HlacaZGW17', 'title': 'On Fairness, Diversity and Randomness in Algorithmic Decision Making.', 'authors': ['Nina Grgic-Hlaca', 'Muhammad Bilal Zafar', 'Krishna P. Gummadi', 'Adrian Weller'], 'year': '2017'}
# {'key': 'journals/corr/GrabowiczGG16', 'title': 'Distinguishing between Topical and Non-topical Information Diffusion Mechanisms in Social Media.', 'authors': ['Przemyslaw A. Grabowicz', 'Niloy Ganguly', 'Krishna P. Gummadi'], 'year': '2016'}
# {'key': 'journals/corr/abs-2201-01180', 'title': 'Towards Fair Recommendation in Two-Sided Platforms.', 'authors': ['Arpita Biswas', 'Gourab K. Patro', 'Niloy Ganguly', 'Krishna P. Gummadi', 'Abhijnan Chakraborty'], 'year': '2022'}
# {'key': 'journals/corr/abs-1806-03281', 'title': 'Blind Justice: Fairness with Encrypted Sensitive Attributes.', 'authors': ['Niki Kilbertus', 'Adri', 'Matt J. Kusner', 'Michael Veale', 'Krishna P. Gummadi', 'Adrian Weller'], 'year': '2018'}
# {'key': 'journals/corr/abs-2106-02970', 'title': 'Modeling Coordinated vs. P2P Mining: An Analysis of Inefficiency and Inequality in Proof-of-Work Blockchains.', 'authors': ['Mohamed Alzayat', 'Johnnatan Messias', 'Balakrishnan Chandrasekaran 0002', 'Krishna P. Gummadi', 'Patrick Loiseau'], 'year': '2021'}
# {'key': 'journals/corr/abs-1808-09218', 'title': 'On Microtargeting Socially Divisive Ads: A Case Study of Russia-Linked Ad Campaigns on Facebook.', 'authors': ['Filipe Nunes Ribeiro', 'Koustuv Saha', 'Mahmoudreza Babaei', 'Lucas Henrique C. Lima', 'Johnnatan Messias', 'Oana Goga', 'Fabr', 'Krishna P. Gummadi', 'Elissa M. Redmiles'], 'year': '2018'}
# {'key': 'journals/corr/ZafarVGG15', 'title': 'Fairness Constraints: A Mechanism for Fair Classification.', 'authors': ['Muhammad Bilal Zafar', 'Isabel Valera', 'Manuel Gomez-Rodriguez', 'Krishna P. Gummadi'], 'year': '2015'}
# {'key': 'journals/corr/ZafarVGGW17', 'title': 'From Parity to Preference-based Notions of Fairness in Classification.', 'authors': ['Muhammad Bilal Zafar', 'Isabel Valera', 'Manuel Gomez-Rodriguez', 'Krishna P. Gummadi', 'Adrian Weller'], 'year': '2017'}
# {'key': 'journals/corr/abs-2202-03934', 'title': 'Alexa, in you, I trust! Fairness and Interpretability Issues in E-commerce Search through Smart Speakers.', 'authors': ['Abhisek Dash', 'Abhijnan Chakraborty', 'Saptarshi Ghosh 0001', 'Animesh Mukherjee 0001', 'Krishna P. Gummadi'], 'year': '2022'}
# {'key': 'journals/corr/abs-1812-01504', 'title': 'Fighting Fire with Fire: Using Antidote Data to Improve Polarization and Fairness of Recommender Systems.', 'authors': ['Bashir Rastegarpanah', 'Krishna P. Gummadi', 'Mark Crovella'], 'year': '2018'}
# {'key': 'journals/corr/abs-2006-13699', 'title': 'On Fair Selection in the Presence of Implicit Variance.', 'authors': ['Vitalii Emelianov', 'Nicolas Gast', 'Krishna P. Gummadi', 'Patrick Loiseau'], 'year': '2020'}
# {'key': 'journals/corr/FerreiraZG16', 'title': 'The Case for Temporal Transparency: Detecting Policy Change Events in Black-Box Decision Making Systems.', 'authors': ['Miguel Ferreira', 'Muhammad Bilal Zafar', 'Krishna P. Gummadi'], 'year': '2016'}
# {'key': 'journals/corr/KulshresthaZNGG17', 'title': 'Characterizing Information Diets of Social Media Users.', 'authors': ['Juhi Kulshrestha', 'Muhammad Bilal Zafar', 'Lisette Espin Noboa', 'Krishna P. Gummadi', 'Saptarshi Ghosh 0001'], 'year': '2017'}
# {'key': 'journals/corr/abs-2111-14726', 'title': 'Exploring Alignment of Representations with Human Perception.', 'authors': ['Vedant Nanda', 'Ayan Majumdar', 'Camila Kolling', 'John P. Dickerson', 'Krishna P. Gummadi', 'Bradley C. Love', 'Adrian Weller'], 'year': '2021'}
# {'key': 'journals/corr/abs-1910-10255', 'title': 'An Empirical Study on Learning Fairness Metrics for COMPAS Data with Human Supervision.', 'authors': ['Hanchen Wang', 'Nina Grgic-Hlaca', 'Preethi Lahoti', 'Krishna P. Gummadi', 'Adrian Weller'], 'year': '2019'}
# {'key': 'journals/corr/abs-2110-11740', 'title': 'Selfish  Opaque Transaction Ordering in the Bitcoin Blockchain: The Case for Chain Neutrality.', 'authors': ['Johnnatan Messias', 'Mohamed Alzayat', 'Balakrishnan Chandrasekaran 0002', 'Krishna P. Gummadi', 'Patrick Loiseau', 'Alan Mislove'], 'year': '2021'}
# {'key': 'journals/corr/abs-2301-04945', 'title': 'Leveraging Rights of Data Subjects for Social Media Analysis: Studying TikTok via Data Donations.', 'authors': ['Savvas Zannettou', 'Olivia-Nemes Nemeth', 'Oshrat Ayalon', 'Angelica Goetzen', 'Krishna P. Gummadi', 'Elissa M. Redmiles', 'Franziska Roesner'], 'year': '2023'}
# {'key': 'journals/corr/abs-1906-06613', 'title': 'The Price of Local Fairness in Multistage Selection.', 'authors': ['Vitalii Emelianov', 'George Arvanitakis', 'Nicolas Gast', 'Krishna P. Gummadi', 'Patrick Loiseau'], 'year': '2019'}
# {'key': 'journals/corr/abs-2302-06962', 'title': 'Dissecting Bitcoin and Ethereum Transactions: On the Lack of Transaction Contention and Prioritization Transparency in Blockchains.', 'authors': ['Johnnatan Messias', 'Vabuk Pahari', 'Balakrishnan Chandrasekaran 0002', 'Krishna P. Gummadi', 'Patrick Loiseau'], 'year': '2023'}
# {'key': 'journals/corr/GogaLSTG15', 'title': 'On the Reliability of Profile Matching Across Large Online Social Networks.', 'authors': ['Oana Goga', 'Patrick Loiseau', 'Robin Sommer', 'Renata Teixeira', 'Krishna P. Gummadi'], 'year': '2015'}
# {'key': 'journals/corr/GrabowiczRLPBG15', 'title': 'An experimental study of opinion influenceability.', 'authors': ['Przemyslaw A. Grabowicz', 'Francisco Romero-Ferrero', 'Theo Lins', 'Gonzalo G. de Polavieja', 'Fabr', 'Krishna P. Gummadi'], 'year': '2015'}
# {'key': 'journals/corr/abs-2105-04273', 'title': 'Loss-Aversively Fair Classification.', 'authors': ['Junaid Ali 0001', 'Muhammad Bilal Zafar', 'Adish Singla', 'Krishna P. Gummadi'], 'year': '2021'}
# {'key': 'journals/corr/abs-2209-03821', 'title': 'Taking Advice from (Dis)Similar Machines: The Impact of Human-Machine Similarity on Machine-Assisted Decision-Making.', 'authors': ['Nina Grgic-Hlaca', 'Claude Castelluccia', 'Krishna P. Gummadi'], 'year': '2022'}
# {'key': 'journals/corr/abs-2010-14624', 'title': 'On Fair Virtual Conference Scheduling: Achieving Equitable Participant and Speaker Satisfaction.', 'authors': ['Gourab K. Patro', 'Abhijnan Chakraborty', 'Niloy Ganguly', 'Krishna P. Gummadi'], 'year': '2020'}
# {'key': 'journals/corr/abs-1811-08690', 'title': 'Equality of Voice: Towards Fair Representation in Crowdsourced Top-K Recommendations.', 'authors': ['Abhijnan Chakraborty', 'Gourab K. Patro', 'Niloy Ganguly', 'Krishna P. Gummadi', 'Patrick Loiseau'], 'year': '2018'}
# {'key': 'journals/corr/abs-1710-11271', 'title': 'Forgetting the Forgotten with Letheia, Concealing Content Deletion from Persistent Observers.', 'authors': ['Mohsen Minaei', 'Mainack Mondal', 'Patrick Loiseau', 'Krishna P. Gummadi', 'Aniket Kate'], 'year': '2017'}
# {'key': 'journals/corr/ZafarVGG16', 'title': 'Fairness Beyond Disparate Treatment  Disparate Impact: Learning Classification without Disparate Mistreatment.', 'authors': ['Muhammad Bilal Zafar', 'Isabel Valera', 'Manuel Gomez-Rodriguez', 'Krishna P. Gummadi'], 'year': '2016'}
# {'key': 'journals/corr/abs-2206-11939', 'title': 'Measuring Representational Robustness of Neural Networks Through Shared Invariances.', 'authors': ['Vedant Nanda', 'Till Speicher', 'Camila Kolling', 'John P. Dickerson', 'Krishna P. Gummadi', 'Adrian Weller'], 'year': '2022'}
# {'key': 'journals/corr/abs-2002-10764', 'title': 'FairRec: Two-Sided Fairness for Personalized Recommendations in Two-Sided Platforms.', 'authors': ['Gourab K. Patro', 'Arpita Biswas', 'Niloy Ganguly', 'Krishna P. Gummadi', 'Abhijnan Chakraborty'], 'year': '2020'}
# {'key': 'journals/corr/abs-1805-01788', 'title': 'Equity of Attention: Amortizing Individual Fairness in Rankings.', 'authors': ['Asia J. Biega', 'Krishna P. Gummadi', 'Gerhard Weikum'], 'year': '2018'}
# {'key': 'journals/corr/ValeraGG14', 'title': 'Modeling Diffusion of Competing Products and Conventions in Social Media.', 'authors': ['Isabel Valera', 'Manuel Gomez-Rodriguez', 'Krishna P. Gummadi'], 'year': '2014'}
# {'key': 'journals/corr/abs-1909-05583', 'title': 'Minimizing Margin of Victory for Fair Political and Educational Districting.', 'authors': ['Ana-Andreea Stoica', 'Abhijnan Chakraborty', 'Palash Dey', 'Krishna P. Gummadi'], 'year': '2019'}
# {'key': 'journals/corr/abs-1905-06618', 'title': 'On the Fairness of Time-Critical Influence Maximization in Social Networks.', 'authors': ['Junaid Ali 0001', 'Mahmoudreza Babaei', 'Abhijnan Chakraborty', 'Baharan Mirzasoleiman', 'Krishna P. Gummadi', 'Adish Singla'], 'year': '2019'}
# {'key': 'journals/corr/abs-1910-13983', 'title': 'DADI: Dynamic Discovery of Fair Information with Adversarial Reinforcement Learning.', 'authors': ['Michiel A. Bakker', 'Duy Patrick Tu', 'Humberto River', 'Krishna P. Gummadi', 'Kush R. Varshney', 'Adrian Weller', 'Alex Pentland'], 'year': '2019'}
# {'key': 'journals/corr/abs-1907-01439', 'title': 'Operationalizing Individual Fairness with Pairwise Fair Representations.', 'authors': ['Preethi Lahoti', 'Krishna P. Gummadi', 'Gerhard Weikum'], 'year': '2019'}
# {'key': 'journals/corr/Gomez-RodriguezGS14', 'title': 'Quantifying Information Overload in Social Media and its Impact on Social Contagions.', 'authors': ['Manuel Gomez-Rodriguez', 'Krishna P. Gummadi', 'Bernhard Sch'], 'year': '2014'}
# {'key': 'journals/corr/abs-1802-09548', 'title': 'Human Perceptions of Fairness in Algorithmic Decision Making: A Case Study of Criminal Risk Prediction.', 'authors': ['Nina Grgic-Hlaca', 'Elissa M. Redmiles', 'Krishna P. Gummadi', 'Adrian Weller'], 'year': '2018'}
# {'key': 'journals/corr/abs-1909-10005', 'title': 'Incremental Fairness in Two-Sided Market Platforms: On Updating Recommendations Fairly.', 'authors': ['Gourab K. Patro', 'Abhijnan Chakraborty', 'Niloy Ganguly', 'Krishna P. Gummadi'], 'year': '2019'}
# {'key': 'journals/corr/abs-2105-04249', 'title': 'Accounting for Model Uncertainty in Algorithmic Discrimination.', 'authors': ['Junaid Ali 0001', 'Preethi Lahoti', 'Krishna P. Gummadi'], 'year': '2021'}
# {'key': 'journals/pvldb/LahotiGW19', 'title': 'Operationalizing Individual Fairness with Pairwise Fair Representations.', 'authors': ['Preethi Lahoti', 'Krishna P. Gummadi', 'Gerhard Weikum'], 'year': '2019'}
# {'key': 'journals/epjds/AnQCGC14', 'title': 'Sharing political news: the balancing act of intimacy and socialization in selective exposure.', 'authors': ['Jisun An', 'Daniele Quercia', 'Meeyoung Cha', 'Krishna P. Gummadi', 'Jon Crowcroft'], 'year': '2014'}
# ---
# Researcher: Christoph Dietzel
# Google Sheets Data:
#                  Name                             email  \
# 40  Christoph Dietzel  christoph.dietzel@mpi-inf.mpg.de
#
#                              Institution              Expertise Region  \
# 40  Max-Planck Institute for Informatics  MEASUREMENT,SECURITY,     EU
#
#    Approximate PhD Graduation Year  Female or NB  Industry
# 40                             NaN           NaN       NaN
# XML Records:
# {'key': 'journals/cm/ChiesaDABCGK0NO16', 'title': 'Inter-domain networking innovation on steroids: empowering ixps with SDN capabilities.', 'authors': ['Marco Chiesa', 'Christoph Dietzel', 'Gianni Antichi', 'Marc Bruyere', 'Ignacio Castro', 'Mitch Gusat', 'Thomas King', 'Andrew W. Moore 0002', 'Thanh Dang Nguyen', 'Philippe Owezarski', 'Steve Uhlig', 'Marco Canini'], 'year': '2016'}
# {'key': 'journals/ccr/MarcosCDCB20', 'title': 'A survey on the current internet interconnection practices.', 'authors': ['Pedro de B. Marcos', 'Marco Chiesa', 'Christoph Dietzel', 'Marco Canini', 'Marinho P. Barcellos'], 'year': '2020'}
# {'key': 'journals/ton/GiotsasNKSGMDKD21', 'title': 'O Peer, Where Art Thou? Uncovering Remote Peering Interconnections at IXPs.', 'authors': ['Vasileios Giotsas', 'George Nomikos', 'Vasileios Kotronis', 'Pavlos Sermpezis', 'Petros Gigis', 'Lefteris Manassakis', 'Christoph Dietzel', 'Stavros Konstantaras', 'Xenofontas A. Dimitropoulos'], 'year': '2021'}
# {'key': 'journals/jsac/AntichiCCFLKHBD17', 'title': 'ENDEAVOUR: A Scalable SDN Architecture For Real-World IXPs.', 'authors': ['Gianni Antichi', 'Ignacio Castro', 'Marco Chiesa', 'Eder Le', 'Remy Lapeyrade', 'Daniel Kopp', 'Jong Hun Han', 'Marc Bruyere', 'Christoph Dietzel', 'Mitchell Gusat', 'Andrew W. Moore 0002', 'Philippe Owezarski', 'Steve Uhlig', 'Marco Canini'], 'year': '2017'}
# {'key': 'journals/corr/abs-1801-05168', 'title': 'A First Look at QUIC in the Wild.', 'authors': ['Jan R', 'Ingmar Poese', 'Christoph Dietzel', 'Oliver Hohlfeld'], 'year': '2018'}
# {'key': 'journals/corr/abs-2008-10959', 'title': 'The Lockdown Effect: Implications of the COVID-19 Pandemic on Internet Traffic.', 'authors': ['Anja Feldmann', 'Oliver Gasser', 'Franziska Lichtblau', 'Enric Pujol', 'Ingmar Poese', 'Christoph Dietzel', 'Daniel Wagner', 'Matthias Wichtlhuber', 'Juan Tapiador', 'Narseo Vallina-Rodriguez', 'Oliver Hohlfeld', 'Georgios Smaragdakis'], 'year': '2020'}
# {'key': 'journals/corr/abs-2103-04443', 'title': 'DDoS Never Dies? An IXP Perspective on DDoS Amplification Attacks.', 'authors': ['Daniel Kopp', 'Christoph Dietzel', 'Oliver Hohlfeld'], 'year': '2021'}
# {'key': 'journals/corr/abs-1911-04924', 'title': 'O Peer, Where Art Thou? Uncovering Remote Peering Interconnections at IXPs.', 'authors': ['George Nomikos', 'Vasileios Kotronis', 'Pavlos Sermpezis', 'Petros Gigis', 'Lefteris Manassakis', 'Christoph Dietzel', 'Stavros Konstantaras', 'Xenofontas A. Dimitropoulos', 'Vasileios Giotsas'], 'year': '2019'}
# {'key': 'journals/corr/abs-1909-07455', 'title': 'DDoS Hide  Seek: On the Effectiveness of a Booter Services Takedown.', 'authors': ['Daniel Kopp', 'Matthias Wichtlhuber', 'Ingmar Poese', 'Jair Santanna', 'Oliver Hohlfeld', 'Christoph Dietzel'], 'year': '2019'}
# {'key': 'journals/cacm/FeldmannGLPPDWW21', 'title': 'A year in lockdown: how the waves of COVID-19 impact internet traffic.', 'authors': ['Anja Feldmann', 'Oliver Gasser', 'Franziska Lichtblau', 'Enric Pujol', 'Ingmar Poese', 'Christoph Dietzel', 'Daniel Wagner', 'Matthias Wichtlhuber', 'Juan Tapiador', 'Narseo Vallina-Rodriguez', 'Oliver Hohlfeld', 'Georgios Smaragdakis'], 'year': '2021'}
# {'key': 'journals/rfc/rfc7999', 'title': 'BLACKHOLE Community.', 'authors': ['Thomas King', 'Christoph Dietzel', 'Job Snijders', 'Gert Doering', 'Greg Hankins'], 'year': '2016'}
# ---
# Researcher: Raghav Subbaraman
# Google Sheets Data:
#                   Name                     email  \
# 455  Raghav Subbaraman  rsubbaraman@eng.ucsd.edu
#
#                             Institution  Expertise Region  \
# 455  University of California San Diego  WIRELESS,    NaN
#
#     Approximate PhD Graduation Year  Female or NB  Industry
# 455                             NaN           NaN       NaN
# XML Records:
# {'key': 'journals/jssc/AbolmagdSEGSBS23', 'title': 'A Hierarchical Self-Interference Canceller for Full-Duplex LPWAN Applications Achieving 52-70-dB RF Cancellation.', 'authors': ['Hany Abolmagd', 'Raghav Subbaraman', 'Omid Esmaeeli', 'Yeswanth Guntupalli', 'Ahmad Sharkia', 'Dinesh Bharadia', 'Sudip Shekhar'], 'year': '2023'}
# {'key': 'journals/sigmobile/GuddetiSKSB20', 'title': 'Towards Low-cost, Ubiquitous High-time Resolution Sensing for Terrestrial Spectrum.', 'authors': ['Yeswanth Guddeti', 'Raghav Subbaraman', 'Moein Khazraee', 'Aaron Schulman', 'Dinesh Bharadia'], 'year': '2020'}
# {'key': 'journals/sigmobile/GuptaGDZSMB21', 'title': 'Expanding the Horizons of Wireless Sensing: Sensing and localizing contact forces with signal reflections.', 'authors': ['Agrim Gupta', 'C', 'Manideep Dunna', 'Qiming Zhang 0003', 'Raghav Subbaraman', 'Tania K. Morimoto', 'Dinesh Bharadia'], 'year': '2021'}
# {'key': 'journals/corr/abs-2301-10950', 'title': 'mmFlexible: Flexible Directional Frequency Multiplexing for Multi-user mmWave Networks.', 'authors': ['Ish Kumar Jain', 'Rohith Reddy Vennam', 'Raghav Subbaraman', 'Dinesh Bharadia'], 'year': '2023'}
# {'key': 'journals/corr/abs-2101-04249', 'title': 'Two beams are better than one: Enabling reliable and high throughput mmWave links.', 'authors': ['Ish Kumar Jain', 'Raghav Subbaraman', 'Dinesh Bharadia'], 'year': '2021'}
# ---
# <ipython-input-28-f05aecb819a2>:53: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random_authors = random.sample(common_authors, k=3)

# %% [markdown]
# **Merge the XML and the CSV to reate three output files:**
#
# *   Matched with data from Researcher CSV & DBLP XML - all the publications detailed are pulled from the XML and listed for each researcher
# *   Unmatched file - Researcher name does not match with DBLP XML, needs to fix input data file, such as spelling, special characters, etc.
# *   Matched file with just name - We can use this file for further fine tuning the program. We will skip records from processing, if found in match file. This enhancement is not there yet.

# %%
import gzip
from lxml import etree
from google.colab import drive
import unicodedata

# Mount Google Drive
drive.mount('/content/drive')

# Function to extract author names
def extract_authors(element):
    authors = []
    for author_elem in element.xpath("author"):
        authors.append(author_elem.text)
    return authors

# Create a dictionary to store XML records indexed by researcher name
xml_records = {}

# Process the DBLP XML file
with gzip.open("dblp.xml.gz", "rb") as f:
    context = etree.iterparse(f, events=("start", "end"), recover=True)

    for event, element in context:
        if element.tag == 'article':
            # Extract the article key, title, authors, and year
            article_key = element.get('key')
            article_title = element.xpath('title')
            if article_title:
                article_title = article_title[0].text
            else:
                article_title = 'N/A'
            article_authors = extract_authors(element)
            article_year = element.xpath('year')
            if article_year:
                article_year = article_year[0].text
            else:
                article_year = 'N/A'

            # Add the record to the dictionary indexed by each author's name
            for author in article_authors:
                if author not in xml_records:
                    xml_records[author] = []
                xml_records[author].append({
                    'key': article_key,
                    'title': article_title,
                    'authors': article_authors,
                    'year': article_year
                })

        # Clear the processed elements to free up memory
        element.clear()

# Create files in Google Drive to store the results
output_file_path = '/content/drive/MyDrive/Output.txt'
matches_file_path = '/content/drive/MyDrive/Matches.txt'
non_matches_file_path = '/content/drive/MyDrive/NonMatches.txt'

# Open the files in write mode
with open(output_file_path, 'w') as output_file, \
     open(matches_file_path, 'w') as matches_file, \
     open(non_matches_file_path, 'w') as non_matches_file:

    for _, row in dfResearcher.iterrows():
        researcher_name = row['Name']
        encoded_researcher_name = unicodedata.normalize('NFKD', researcher_name).encode('utf-8', 'ignore').decode('utf-8')

        # Check if the researcher exists in the XML records
        if researcher_name in xml_records:
            # Write the researcher name and their corresponding information to the output file
            output_file.write('Researcher: {}\n'.format(researcher_name))
            output_file.write('Google Sheets Data:\n')
            output_file.write(row.to_string())
            output_file.write('\n')
            output_file.write('XML Records:\n')
            for record in xml_records[researcher_name]:
                output_file.write(str(record))
                output_file.write('\n')
            output_file.write('---\n')

            # Write the researcher name to the matches file
            matches_file.write(str(researcher_name))
            matches_file.write('\n')
        else:
            # Write the researcher name to the non-matches file
            non_matches_file.write(str(researcher_name))
            non_matches_file.write('\n')

# Print the paths of the output files in Google Drive
print('Output file saved to:', output_file_path)
print('Matches file saved to:', matches_file_path)
print('Non-Matches file saved to:', non_matches_file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Output file saved to: /content/drive/MyDrive/Output.txt
# Matches file saved to: /content/drive/MyDrive/Matches.txt
# Non-Matches file saved to: /content/drive/MyDrive/NonMatches.txt
